# %%
import pandas as pd

# %%
filepath = "../make-ipinyou-data/1458/train.log.txt"
d = pd.read_csv(filepath, delim_whitespace=True)

# %%
print(d.columns)
pd.set_option('display.max_columns', 500)
d.head(10)
# Out:
# Index(['click', 'weekday', 'hour', 'bidid', 'timestamp', 'logtype',
#        'ipinyouid', 'useragent', 'IP', 'region', 'city', 'adexchange',
#        'domain', 'url', 'urlid', 'slotid', 'slotwidth', 'slotheight',
#        'slotvisibility', 'slotformat', 'slotprice', 'creative', 'bidprice',
#        'payprice', 'keypage', 'advertiser', 'usertag'],
#       dtype='object')
#    click  weekday  hour                             bidid          timestamp  \
# 0      0        4     0  81aced04baad90f9358aa39a4521cd6f  20130606000104828
# 1      0        4     0    572fa35095e8b6c30b1aa871e52b2d  20130606000105075
# 2      0        4     0   e1e44b8a725b957a626991ecb15b56f  20130606000105119
# 3      0        4     0  f250658c8cfc615c824f9552497d6325  20130606000105254
# 4      0        4     0  125f1b570af0b42341eb60a532544f0b  20130606000105284
# 5      0        4     0  3a799517748639990b899fc611ec8830  20130606000105302
# ...

# %%
grouped = d.groupby("bidid")

# %%
print(d["click"].unique())
# Out:
# [0 1]
